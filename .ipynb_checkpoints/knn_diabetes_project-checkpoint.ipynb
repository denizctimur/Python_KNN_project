# %% [markdown]
# ## KNN - K Nearest Neighbours
# Importing required libraries pandas, numpy and matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Importing sklearn training model and KNN

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
data = pd.read_csv("diabetes.csv")
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## Modeling our data with their age and glucose values just for looking

# %%
diabetes_people = data[data.Outcome == 1]
healhty_people = data[data.Outcome == 0]

plt.scatter(diabetes_people.Age, diabetes_people.Glucose, color="red", label="Diabetes People", alpha=0.4)
plt.scatter(healhty_people.Age, healhty_people.Glucose, color="green", label="Healthy People", alpha=0.4)
plt.xlabel("Age")
plt.ylabel("Glucose")
plt.legend()
plt.show()

# %% [markdown]
# ## Parsing data for training and normalizing

# %%
x = data.drop(["Outcome"], axis=1)
y = data.Outcome.values

# %% [markdown]
# ## Normalization data

# %%
x_normalized = ( x - np.min(x) ) / ( np.max(x) - np.min(x) )

print("Normalized Data:\n")
print(x_normalized.head())
print("\n\n\n\nWithout Normalizing Data:\n\n")
print(x.head())
# Out:
# Normalized Data:
#
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#    DiabetesPedigreeFunction       Age
# 0                  0.234415  0.483333
# 1                  0.116567  0.166667
# 2                  0.253629  0.183333
# 3                  0.038002  0.000000
# 4                  0.943638  0.200000
#
#
#
#
# Without Normalizing Data:
#
#
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# ...
